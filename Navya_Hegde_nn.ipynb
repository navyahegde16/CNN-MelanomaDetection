# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %%
from google.colab import drive
drive.mount('/content/gdrive' , force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, Conv2D, MaxPooling2D
from tensorflow.keras.regularizers import l2

# %%
## If you are using the data by mounting the google drive, use the following :
## from google.colab import drive
## drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# This assignment uses a dataset of about 2293 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
root_path = '/content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration'
data_dir_train = pathlib.Path(root_path + '/Train')
data_dir_test = pathlib.Path(root_path + '/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2247
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset

train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir_train,
    labels='inferred',
    label_mode='int',
    class_names=None,
    color_mode='rgb',
    batch_size=batch_size,
    image_size=(img_height, img_width),
    shuffle=True,
    seed=123,
    validation_split=0.2,
    subset='training',
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=True
)
# Out:
# Found 2247 files belonging to 9 classes.
# Using 1798 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir_train,
    labels='inferred',
    label_mode='int',
    class_names=None,
    color_mode='rgb',
    batch_size=batch_size,
    image_size=(img_height, img_width),
    shuffle=True,
    seed=123,
    validation_split=0.2,
    subset='validation',
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=True
)
# Out:
# Found 2247 files belonging to 9 classes.
# Using 449 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

### your code goes here, you can use training or validation data to visualize
num_classes = len(class_names)

fig = plt.figure(figsize=(25,5))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    im = plt.imread(str(list(data_dir_train.glob(class_names[i]+'/*.jpg'))[1]))
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here
model = Sequential([layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))])

model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', input_shape = (180, 180, 32)))
model.add(Activation('relu'))
#model.add(BatchNormalization())
model.add(Conv2D(32, (5, 5)))
model.add(Activation('relu'))
#model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(32, (3, 3), padding='same'))
model.add(Activation('relu'))
#model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
#model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
#model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
#model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
# model.add(Dense(512,kernel_regularizer=l2(0.01)))
# model.add(Activation('relu'))
# model.add(Dropout(0.5))

model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      2432
#
#  activation (Activation)     (None, 180, 180, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 176, 176, 32)      25632
#
#  activation_1 (Activation)   (None, 176, 176, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 88, 88, 32)       0
#  )
#
#  dropout (Dropout)           (None, 88, 88, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 88, 88, 32)        9248
#
#  activation_2 (Activation)   (None, 88, 88, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 86, 86, 32)        9248
#
#  activation_3 (Activation)   (None, 86, 86, 32)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 43, 43, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 43, 43, 64)        18496
#
#  activation_4 (Activation)   (None, 43, 43, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 41, 41, 64)        36928
#
#  activation_5 (Activation)   (None, 41, 41, 64)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 20, 20, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 20, 20, 64)        0
#
#  flatten (Flatten)           (None, 25600)             0
#
#  dense (Dense)               (None, 9)                 230409
#
#  activation_6 (Activation)   (None, 9)                 0
#
# =================================================================
# Total params: 332,393
# Trainable params: 332,393
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  batch_size=batch_size,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 57/57 [==============================] - 276s 985ms/step - loss: 2.0547 - accuracy: 0.1941 - val_loss: 2.0339 - val_accuracy: 0.1871
# Epoch 2/20
# 57/57 [==============================] - 4s 78ms/step - loss: 2.0264 - accuracy: 0.2058 - val_loss: 2.0364 - val_accuracy: 0.1782
# Epoch 3/20
# 57/57 [==============================] - 4s 77ms/step - loss: 2.0067 - accuracy: 0.2052 - val_loss: 1.9925 - val_accuracy: 0.2138
# Epoch 4/20
# 57/57 [==============================] - 4s 77ms/step - loss: 1.9282 - accuracy: 0.2875 - val_loss: 1.8928 - val_accuracy: 0.2762
# Epoch 5/20
# 57/57 [==============================] - 4s 77ms/step - loss: 1.8246 - accuracy: 0.3337 - val_loss: 1.9040 - val_accuracy: 0.2606
# Epoch 6/20
# 57/57 [==============================] - 4s 77ms/step - loss: 1.7771 - accuracy: 0.3626 - val_loss: 1.7795 - val_accuracy: 0.3118
# Epoch 7/20
# 57/57 [==============================] - 4s 77ms/step - loss: 1.7084 - accuracy: 0.3765 - val_loss: 1.7995 - val_accuracy: 0.3497
# Epoch 8/20
# 57/57 [==============================] - 4s 77ms/step - loss: 1.6555 - accuracy: 0.4171 - val_loss: 1.6019 - val_accuracy: 0.4076
# Epoch 9/20
# 57/57 [==============================] - 4s 77ms/step - loss: 1.6524 - accuracy: 0.4082 - val_loss: 1.8986 - val_accuracy: 0.2717
# Epoch 10/20
# 57/57 [==============================] - 4s 77ms/step - loss: 1.5402 - accuracy: 0.4438 - val_loss: 1.5232 - val_accuracy: 0.4410
# Epoch 11/20
# 57/57 [==============================] - 4s 77ms/step - loss: 1.5038 - accuracy: 0.4616 - val_loss: 1.5568 - val_accuracy: 0.4588
# Epoch 12/20
# 57/57 [==============================] - 4s 78ms/step - loss: 1.4561 - accuracy: 0.4828 - val_loss: 1.5156 - val_accuracy: 0.4477
# Epoch 13/20
# 57/57 [==============================] - 4s 77ms/step - loss: 1.4772 - accuracy: 0.4739 - val_loss: 1.5211 - val_accuracy: 0.4655
# Epoch 14/20
# 57/57 [==============================] - 4s 77ms/step - loss: 1.5840 - accuracy: 0.4583 - val_loss: 1.6415 - val_accuracy: 0.4120
# Epoch 15/20
# 57/57 [==============================] - 4s 77ms/step - loss: 1.4599 - accuracy: 0.4778 - val_loss: 1.5616 - val_accuracy: 0.4254
# Epoch 16/20
# 57/57 [==============================] - 4s 77ms/step - loss: 1.4444 - accuracy: 0.4794 - val_loss: 1.5303 - val_accuracy: 0.4410
# Epoch 17/20
# 57/57 [==============================] - 4s 77ms/step - loss: 1.3634 - accuracy: 0.5067 - val_loss: 1.6453 - val_accuracy: 0.4454
# Epoch 18/20
# 57/57 [==============================] - 4s 77ms/step - loss: 1.3736 - accuracy: 0.5111 - val_loss: 1.5304 - val_accuracy: 0.4699
# Epoch 19/20
# 57/57 [==============================] - 4s 77ms/step - loss: 1.3861 - accuracy: 0.5000 - val_loss: 1.4897 - val_accuracy: 0.4633
# Epoch 20/20
# 57/57 [==============================] - 4s 77ms/step - loss: 1.3226 - accuracy: 0.5306 - val_loss: 1.4780 - val_accuracy: 0.4722

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here

# %%
loss, accuracy = model.evaluate(train_ds, verbose=1)
val_loss, val_accuracy = model.evaluate(val_ds, verbose=1)

print("Accuracy", accuracy)
print("loss", loss)
print("val_accuracy", val_accuracy)
print("val_loss", val_loss)
# Out:
# 57/57 [==============================] - 2s 27ms/step - loss: 1.2818 - accuracy: 0.5423
# 15/15 [==============================] - 0s 25ms/step - loss: 1.4780 - accuracy: 0.4722
# Accuracy 0.5422691702842712
# loss 1.2817579507827759
# val_accuracy 0.47216036915779114
# val_loss 1.4780186414718628

# %% [markdown]
# - The Loss difference is significant.
# - There's a significant difference between the train and validation accuracy.
# -Since the model performed really well with train data but not so well with validation data, this is clearly an overfit model.

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
# Your code goes here
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical",input_shape=(img_height,img_width,3)),
  layers.RandomRotation(0.2,fill_mode='reflect'),
  layers.RandomContrast(0.5, seed=None),
  layers.RandomZoom((0.2, 0.3),width_factor=(0.2, 0.3), fill_mode='reflect')
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here
plt.figure(figsize=(15, 15))
for images, labels in train_ds.take(1):
    for i in range(num_classes):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(data_augmentation(images)[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here
model = Sequential([data_augmentation,layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))])

model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', input_shape = (180, 180, 32)))
model.add(Activation('relu'))
#model.add(BatchNormalization())
model.add(Conv2D(32, (5, 5)))
model.add(Activation('relu'))
#model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(32, (3, 3), padding='same'))
model.add(Activation('relu'))
#model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
#model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
#model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
#model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
# model.add(Dense(512,kernel_regularizer=l2(0.01)))
# model.add(Activation('relu'))
# model.add(Dropout(0.5))

model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs

epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  batch_size=batch_size,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 57/57 [==============================] - 6s 85ms/step - loss: 2.0586 - accuracy: 0.2002 - val_loss: 2.0375 - val_accuracy: 0.2004
# Epoch 2/20
# 57/57 [==============================] - 5s 82ms/step - loss: 2.0304 - accuracy: 0.1930 - val_loss: 2.0297 - val_accuracy: 0.2004
# Epoch 3/20
# 57/57 [==============================] - 5s 83ms/step - loss: 2.0250 - accuracy: 0.1852 - val_loss: 2.0327 - val_accuracy: 0.2004
# Epoch 4/20
# 57/57 [==============================] - 5s 81ms/step - loss: 2.0197 - accuracy: 0.2047 - val_loss: 2.0294 - val_accuracy: 0.1871
# Epoch 5/20
# 57/57 [==============================] - 5s 81ms/step - loss: 2.0220 - accuracy: 0.2019 - val_loss: 2.0327 - val_accuracy: 0.2004
# Epoch 6/20
# 57/57 [==============================] - 5s 81ms/step - loss: 2.0203 - accuracy: 0.1980 - val_loss: 2.0285 - val_accuracy: 0.2004
# Epoch 7/20
# 57/57 [==============================] - 5s 81ms/step - loss: 2.0204 - accuracy: 0.2013 - val_loss: 2.0272 - val_accuracy: 0.2004
# Epoch 8/20
# 57/57 [==============================] - 5s 82ms/step - loss: 2.0208 - accuracy: 0.1980 - val_loss: 2.0239 - val_accuracy: 0.2004
# Epoch 9/20
# 57/57 [==============================] - 5s 81ms/step - loss: 2.0216 - accuracy: 0.2019 - val_loss: 2.0259 - val_accuracy: 0.2004
# Epoch 10/20
# 57/57 [==============================] - 5s 80ms/step - loss: 2.0238 - accuracy: 0.2008 - val_loss: 2.0275 - val_accuracy: 0.1849
# Epoch 11/20
# 57/57 [==============================] - 5s 80ms/step - loss: 2.0182 - accuracy: 0.2008 - val_loss: 2.0279 - val_accuracy: 0.1871
# Epoch 12/20
# 57/57 [==============================] - 5s 81ms/step - loss: 2.0200 - accuracy: 0.2063 - val_loss: 2.0289 - val_accuracy: 0.2004
# Epoch 13/20
# 57/57 [==============================] - 5s 81ms/step - loss: 2.0168 - accuracy: 0.1991 - val_loss: 2.0261 - val_accuracy: 0.1871
# Epoch 14/20
# 57/57 [==============================] - 5s 81ms/step - loss: 2.0141 - accuracy: 0.2041 - val_loss: 2.0269 - val_accuracy: 0.2004
# Epoch 15/20
# 57/57 [==============================] - 5s 81ms/step - loss: 2.0176 - accuracy: 0.2036 - val_loss: 2.0262 - val_accuracy: 0.2004
# Epoch 16/20
# 57/57 [==============================] - 5s 81ms/step - loss: 2.0241 - accuracy: 0.1969 - val_loss: 2.0266 - val_accuracy: 0.1871
# Epoch 17/20
# 57/57 [==============================] - 5s 81ms/step - loss: 2.0182 - accuracy: 0.2036 - val_loss: 2.0348 - val_accuracy: 0.2004
# Epoch 18/20
# 57/57 [==============================] - 5s 81ms/step - loss: 2.0141 - accuracy: 0.2069 - val_loss: 2.0287 - val_accuracy: 0.2004
# Epoch 19/20
# 57/57 [==============================] - 5s 81ms/step - loss: 2.0129 - accuracy: 0.2108 - val_loss: 2.0243 - val_accuracy: 0.2004
# Epoch 20/20
# 57/57 [==============================] - 5s 81ms/step - loss: 2.0177 - accuracy: 0.1963 - val_loss: 2.0282 - val_accuracy: 0.2004

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %%
loss, accuracy = model.evaluate(train_ds, verbose=1)
val_loss, val_accuracy = model.evaluate(val_ds, verbose=1)

print("Accuracy", accuracy)
print("loss", loss)
print("val_accuracy", val_accuracy)
print("val_loss", val_loss)
# Out:
# 57/57 [==============================] - 2s 27ms/step - loss: 2.0124 - accuracy: 0.2069
# 15/15 [==============================] - 0s 25ms/step - loss: 2.0282 - accuracy: 0.2004
# Accuracy 0.2068965584039688
# loss 2.0123813152313232
# val_accuracy 0.20044542849063873
# val_loss 2.02815318107605

# %% [markdown]
# - There is some reduction in the accuracy
# - But Data augentation has solved the problem of overfitting
# - Accuracy has reduced which can be increased by increasing number of epochs.

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
path_list=[]
lesion_list=[]
for i in class_names:
    for j in data_dir_train.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
df_dict = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(df_dict.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/gdrive/MyDrive/CNN_assignment/Skin ca...  actinic keratosis
# 1     /content/gdrive/MyDrive/CNN_assignment/Skin ca...  actinic keratosis
# 2     /content/gdrive/MyDrive/CNN_assignment/Skin ca...  actinic keratosis
# 3     /content/gdrive/MyDrive/CNN_assignment/Skin ca...  actinic keratosis
# 4     /content/gdrive/MyDrive/CNN_assignment/Skin ca...  actinic keratosis
# ...                                                 ...                ...
# 2242  /content/gdrive/MyDrive/CNN_assignment/Skin ca...    vascular lesion
# 2243  /content/gdrive/MyDrive/CNN_assignment/Skin ca...    vascular lesion
# 2244  /content/gdrive/MyDrive/CNN_assignment/Skin ca...    vascular lesion
# 2245  /content/gdrive/MyDrive/CNN_assignment/Skin ca...    vascular lesion
# 2246  /content/gdrive/MyDrive/CNN_assignment/Skin ca...    vascular lesion
#
# [2247 rows x 2 columns]

# %%
count=[]
for i in class_names:
    count.append(len(list(data_dir_train.glob(i+'/*.jpg'))))
plt.figure(figsize=(25,10))
plt.bar(class_names,count)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# - Seborrheic Keratosis has the least number of samples.
#
# #### - Which classes dominate the data in terms proportionate number of samples?
# - Melanoma and Pigmented benign keratosis classes dominate the data.
#
# Actinic keratosis and Dermatofibroma have proportionate number of classes.

# %%
class_names
# Out:
# ['actinic keratosis',
#  'basal cell carcinoma',
#  'dermatofibroma',
#  'melanoma',
#  'nevus',
#  'pigmented benign keratosis',
#  'seborrheic keratosis',
#  'squamous cell carcinoma',
#  'vascular lesion']

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Augmentor
#   Downloading Augmentor-0.2.10-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.0)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.10

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset=pathlib.Path(root_path + '/Train')
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset, save_format='jpg')
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 2247 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F8F760FD810>: 100%|██████████| 500/500 [00:39<00:00, 12.65 Samples/s]
# Initialised with 2247 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F77428D50>: 100%|██████████| 500/500 [00:42<00:00, 11.81 Samples/s]
# Initialised with 2247 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F76CA1190>: 100%|██████████| 500/500 [00:39<00:00, 12.67 Samples/s]
# Initialised with 2247 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F774DB710>: 100%|██████████| 500/500 [00:41<00:00, 12.18 Samples/s]
# Initialised with 2247 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F8F78C95BD0>: 100%|██████████| 500/500 [00:46<00:00, 10.68 Samples/s]
# Initialised with 2247 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F8F77517D50>: 100%|██████████| 500/500 [00:36<00:00, 13.61 Samples/s]
# Initialised with 2247 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F8F79238190>: 100%|██████████| 500/500 [00:40<00:00, 12.47 Samples/s]
# Initialised with 2247 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=576x768 at 0x7F8F7608A590>: 100%|██████████| 500/500 [00:45<00:00, 11.04 Samples/s]
# Initialised with 2247 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F76C8E390>: 100%|██████████| 500/500 [00:41<00:00, 12.13 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
data_dir_train = pathlib.Path("/content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output")
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
for i in class_names:
      
    for j in data_dir_train.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
new_df = pd.DataFrame(list(df_dict.items()),columns = ['Path','Label'])
new_df
# Out:
#                                                    Path              Label
# 0     /content/gdrive/MyDrive/CNN_assignment/Skin ca...  actinic keratosis
# 1     /content/gdrive/MyDrive/CNN_assignment/Skin ca...  actinic keratosis
# 2     /content/gdrive/MyDrive/CNN_assignment/Skin ca...  actinic keratosis
# 3     /content/gdrive/MyDrive/CNN_assignment/Skin ca...  actinic keratosis
# 4     /content/gdrive/MyDrive/CNN_assignment/Skin ca...  actinic keratosis
# ...                                                 ...                ...
# 2242  /content/gdrive/MyDrive/CNN_assignment/Skin ca...    vascular lesion
# 2243  /content/gdrive/MyDrive/CNN_assignment/Skin ca...    vascular lesion
# 2244  /content/gdrive/MyDrive/CNN_assignment/Skin ca...    vascular lesion
# 2245  /content/gdrive/MyDrive/CNN_assignment/Skin ca...    vascular lesion
# 2246  /content/gdrive/MyDrive/CNN_assignment/Skin ca...    vascular lesion
#
# [2247 rows x 2 columns]

# %%
new_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    462
# melanoma                      438
# basal cell carcinoma          376
# nevus                         365
# squamous cell carcinoma       181
# vascular lesion               139
# actinic keratosis             114
# dermatofibroma                 95
# seborrheic keratosis           77
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

data_dir_train="/content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output"
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4500 files belonging to 9 classes.
# Using 3600 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4500 files belonging to 9 classes.
# Using 900 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## your code goes here
model = Sequential([data_augmentation,layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))])

model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', input_shape = (180, 180, 32)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(32, (5, 5)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(32, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(124, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(124, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
# model.add(Dense(512,kernel_regularizer=l2(0.01)))
# model.add(Activation('relu'))
# model.add(Dropout(0.5))

model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  batch_size=batch_size,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 113/113 [==============================] - 24s 184ms/step - loss: 2.8933 - accuracy: 0.3475 - val_loss: 3.9614 - val_accuracy: 0.2033
# Epoch 2/30
# 113/113 [==============================] - 20s 172ms/step - loss: 2.3678 - accuracy: 0.4006 - val_loss: 3.1212 - val_accuracy: 0.2056
# Epoch 3/30
# 113/113 [==============================] - 21s 174ms/step - loss: 2.4499 - accuracy: 0.4081 - val_loss: 65.1831 - val_accuracy: 0.1911
# Epoch 4/30
# 113/113 [==============================] - 20s 167ms/step - loss: 2.5145 - accuracy: 0.4164 - val_loss: 2.5409 - val_accuracy: 0.3100
# Epoch 5/30
# 113/113 [==============================] - 20s 167ms/step - loss: 2.2248 - accuracy: 0.4317 - val_loss: 580.1975 - val_accuracy: 0.1956
# Epoch 6/30
# 113/113 [==============================] - 20s 168ms/step - loss: 2.4740 - accuracy: 0.4294 - val_loss: 20.5257 - val_accuracy: 0.3467
# Epoch 7/30
# 113/113 [==============================] - 20s 168ms/step - loss: 2.4671 - accuracy: 0.4514 - val_loss: 7.9623 - val_accuracy: 0.2078
# Epoch 8/30
# 113/113 [==============================] - 20s 167ms/step - loss: 2.0877 - accuracy: 0.4594 - val_loss: 3.1332 - val_accuracy: 0.4456
# Epoch 9/30
# 113/113 [==============================] - 20s 167ms/step - loss: 2.1502 - accuracy: 0.4619 - val_loss: 2.6806 - val_accuracy: 0.3722
# Epoch 10/30
# 113/113 [==============================] - 20s 167ms/step - loss: 2.4380 - accuracy: 0.4319 - val_loss: 5.6741 - val_accuracy: 0.2767
# Epoch 11/30
# 113/113 [==============================] - 20s 168ms/step - loss: 2.1568 - accuracy: 0.4608 - val_loss: 1.9687 - val_accuracy: 0.3589
# Epoch 12/30
# 113/113 [==============================] - 20s 167ms/step - loss: 1.9693 - accuracy: 0.4814 - val_loss: 1.7816 - val_accuracy: 0.4144
# Epoch 13/30
# 113/113 [==============================] - 20s 168ms/step - loss: 1.9166 - accuracy: 0.4764 - val_loss: 1.7744 - val_accuracy: 0.4733
# Epoch 14/30
# 113/113 [==============================] - 20s 168ms/step - loss: 1.7542 - accuracy: 0.5031 - val_loss: 1.8477 - val_accuracy: 0.3644
# Epoch 15/30
# 113/113 [==============================] - 20s 168ms/step - loss: 1.7466 - accuracy: 0.4864 - val_loss: 13.4700 - val_accuracy: 0.2367
# Epoch 16/30
# 113/113 [==============================] - 20s 167ms/step - loss: 1.8991 - accuracy: 0.4844 - val_loss: 18.0663 - val_accuracy: 0.2111
# Epoch 17/30
# 113/113 [==============================] - 20s 168ms/step - loss: 1.8327 - accuracy: 0.4922 - val_loss: 22.8878 - val_accuracy: 0.2589
# Epoch 18/30
# 113/113 [==============================] - 20s 168ms/step - loss: 1.7286 - accuracy: 0.5053 - val_loss: 18.9757 - val_accuracy: 0.4233
# Epoch 19/30
# 113/113 [==============================] - 20s 168ms/step - loss: 1.7528 - accuracy: 0.5019 - val_loss: 2.3022 - val_accuracy: 0.2667
# Epoch 20/30
# 113/113 [==============================] - 20s 167ms/step - loss: 1.5354 - accuracy: 0.5244 - val_loss: 1.4349 - val_accuracy: 0.5311
# Epoch 21/30
# 113/113 [==============================] - 20s 167ms/step - loss: 1.4762 - accuracy: 0.5283 - val_loss: 1.5379 - val_accuracy: 0.4900
# Epoch 22/30
# 113/113 [==============================] - 20s 168ms/step - loss: 1.3905 - accuracy: 0.5386 - val_loss: 1.3822 - val_accuracy: 0.5089
# Epoch 23/30
# 113/113 [==============================] - 20s 169ms/step - loss: 1.3610 - accuracy: 0.5422 - val_loss: 1.3531 - val_accuracy: 0.5478
# Epoch 24/30
# 113/113 [==============================] - 20s 168ms/step - loss: 1.3810 - accuracy: 0.5447 - val_loss: 1.4464 - val_accuracy: 0.5167
# Epoch 25/30
# 113/113 [==============================] - 20s 167ms/step - loss: 1.3734 - accuracy: 0.5503 - val_loss: 1.3655 - val_accuracy: 0.5444
# Epoch 26/30
# 113/113 [==============================] - 20s 168ms/step - loss: 1.3932 - accuracy: 0.5475 - val_loss: 1.7327 - val_accuracy: 0.4978
# Epoch 27/30
# 113/113 [==============================] - 20s 168ms/step - loss: 1.3584 - accuracy: 0.5553 - val_loss: 1.5686 - val_accuracy: 0.4600
# Epoch 28/30
# 113/113 [==============================] - 20s 167ms/step - loss: 1.3015 - accuracy: 0.5497 - val_loss: 1.2458 - val_accuracy: 0.5567
# Epoch 29/30
# 113/113 [==============================] - 20s 169ms/step - loss: 1.3078 - accuracy: 0.5525 - val_loss: 1.3957 - val_accuracy: 0.5333
# Epoch 30/30
# 113/113 [==============================] - 20s 168ms/step - loss: 1.2727 - accuracy: 0.5808 - val_loss: 1.3206 - val_accuracy: 0.5489

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %%
loss, accuracy = model.evaluate(train_ds, verbose=1)
val_loss, val_accuracy = model.evaluate(val_ds, verbose=1)

print("Accuracy", accuracy)
print("loss", loss)
print("val_accuracy", val_accuracy)
print("val_loss", val_loss)
# Out:
# 113/113 [==============================] - 16s 128ms/step - loss: 1.2023 - accuracy: 0.5936
# 29/29 [==============================] - 4s 89ms/step - loss: 1.3206 - accuracy: 0.5489
# Accuracy 0.5936111211776733
# loss 1.2022762298583984
# val_accuracy 0.5488888621330261
# val_loss 1.320602297782898

# %% [markdown]
# - Accuracy on training data has increased by using Augmentor library
#
# - Model is underfit.
# - The problem of overfitting can be solved by add more layer,neurons or removing dropout layers.
#
# - The Model can be further improved by tuning the hyperparameter
